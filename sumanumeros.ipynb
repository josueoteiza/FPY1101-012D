# %% [markdown]
# <a href="https://colab.research.google.com/github/josueoteiza/FPY1101-012D/blob/main/sumanumeros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("ingrese numero 1: "))
num2=int(input("ingrese numero 2: "))

sumar=num1 + num2

print("Las suma de dos numeros es:",sumar)
# Out:
# ingrese numero 1: 5
# ingrese numero 2: 2
# Las suma de dos numeros es: 7
